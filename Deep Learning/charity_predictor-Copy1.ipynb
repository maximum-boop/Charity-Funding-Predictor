# %% [markdown]
# # Loading and Processing Data

# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
file_path = 'Resources/charity_data.csv'
data_df = pd.read_csv(file_path)

# %%
data_df.head(5)
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
data_df.dtypes
# Out:
# EIN                        int64
# NAME                      object
# APPLICATION_TYPE          object
# AFFILIATION               object
# CLASSIFICATION            object
# USE_CASE                  object
# ORGANIZATION              object
# STATUS                     int64
# INCOME_AMT                object
# SPECIAL_CONSIDERATIONS    object
# ASK_AMT                    int64
# IS_SUCCESSFUL              int64
# dtype: object

# %%
data_df.nunique()
# Out:
# EIN                       34299
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
data_df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 34294    False
# 34295    False
# 34296    False
# 34297    False
# 34298    False
# Length: 34299, dtype: bool

# %%
data_df["INCOME_AMT"] = data_df["INCOME_AMT"].str.split('-',n=1, expand=True)

# %%
data_df
# Out:
#              EIN                                               NAME  \
# 0       10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1       10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2       10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3       10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4       10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# ...          ...                                                ...
# 34294  996009318              THE LIONS CLUB OF HONOLULU KAMEHAMEHA
# 34295  996010315           INTERNATIONAL ASSOCIATION OF LIONS CLUBS
# 34296  996012607                                PTA HAWAII CONGRESS
# 34297  996015768  AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LO...
# 34298  996086871                           WATERHOUSE CHARITABLE TR
#
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1          0                      N      5000
# 1      Co-operative       1          1                      N    108590
# 2       Association       1          0                      N      5000
# 3             Trust       1      10000                      N      6692
# 4             Trust       1     100000                      N    142590
# ...             ...     ...        ...                    ...       ...
# 34294   Association       1          0                      N      5000
# 34295   Association       1          0                      N      5000
# 34296   Association       1          0                      N      5000
# 34297   Association       1          0                      N      5000
# 34298  Co-operative       1         1M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 12 columns]

# %%
def add(v_range):    
    if "M" in v_range:
        return 10**6
    return v_range

# %%
data_df["INCOME_AMT"] = data_df["INCOME_AMT"].apply(add)

# %%
data_df
# Out:
#              EIN                                               NAME  \
# 0       10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1       10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2       10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3       10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4       10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# ...          ...                                                ...
# 34294  996009318              THE LIONS CLUB OF HONOLULU KAMEHAMEHA
# 34295  996010315           INTERNATIONAL ASSOCIATION OF LIONS CLUBS
# 34296  996012607                                PTA HAWAII CONGRESS
# 34297  996015768  AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LO...
# 34298  996086871                           WATERHOUSE CHARITABLE TR
#
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1          0                      N      5000
# 1      Co-operative       1          1                      N    108590
# 2       Association       1          0                      N      5000
# 3             Trust       1      10000                      N      6692
# 4             Trust       1     100000                      N    142590
# ...             ...     ...        ...                    ...       ...
# 34294   Association       1          0                      N      5000
# 34295   Association       1          0                      N      5000
# 34296   Association       1          0                      N      5000
# 34297   Association       1          0                      N      5000
# 34298  Co-operative       1    1000000                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 12 columns]

# %%
data_df["INCOME_AMT"] = data_df["INCOME_AMT"].astype(str).astype(float)
data_df
# Out:
#              EIN                                               NAME  \
# 0       10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1       10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2       10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3       10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4       10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# ...          ...                                                ...
# 34294  996009318              THE LIONS CLUB OF HONOLULU KAMEHAMEHA
# 34295  996010315           INTERNATIONAL ASSOCIATION OF LIONS CLUBS
# 34296  996012607                                PTA HAWAII CONGRESS
# 34297  996015768  AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LO...
# 34298  996086871                           WATERHOUSE CHARITABLE TR
#
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS  INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1         0.0                      N      5000
# 1      Co-operative       1         1.0                      N    108590
# 2       Association       1         0.0                      N      5000
# 3             Trust       1     10000.0                      N      6692
# 4             Trust       1    100000.0                      N    142590
# ...             ...     ...         ...                    ...       ...
# 34294   Association       1         0.0                      N      5000
# 34295   Association       1         0.0                      N      5000
# 34296   Association       1         0.0                      N      5000
# 34297   Association       1         0.0                      N      5000
# 34298  Co-operative       1   1000000.0                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 12 columns]

# %%
data_df.dtypes
# Out:
# EIN                         int64
# NAME                       object
# APPLICATION_TYPE           object
# AFFILIATION                object
# CLASSIFICATION             object
# USE_CASE                   object
# ORGANIZATION               object
# STATUS                      int64
# INCOME_AMT                float64
# SPECIAL_CONSIDERATIONS     object
# ASK_AMT                     int64
# IS_SUCCESSFUL               int64
# dtype: object

# %% [markdown]
# #### Data Cleaning
# The following is observed from the cells above and correct appropriately:
# 1. We change to change the Income_Amt column from string to integer and carry out a split to obtain the actual amount by defining a function.
# 2. We reduce the number of unique values by binning 'rare' categorical variables.

# %%
data_df['APPLICATION_TYPE'].value_counts(sort=True).reset_index()
# Out:
#    index  APPLICATION_TYPE
# 0     T3             27037
# 1     T4              1542
# 2     T6              1216
# 3     T5              1173
# 4    T19              1065
# 5     T8               737
# 6     T7               725
# 7    T10               528
# 8     T9               156
# 9    T13                66
# 10   T12                27
# 11    T2                16
# 12   T14                 3
# 13   T25                 3
# 14   T15                 2
# 15   T29                 2
# 16   T17                 1

# %%
# Reduce categorical variables (APPLICATION_TYPE)
t_others = data_df['APPLICATION_TYPE'].value_counts().loc[lambda x: x<27]
application_to_replace = t_others.index.tolist()
for t in application_to_replace:
    data_df['APPLICATION_TYPE'] = data_df['APPLICATION_TYPE'].replace(t,"other")
# Confirm binning was successful
data_df['APPLICATION_TYPE'].value_counts(sort=True).reset_index()
# Out:
#     index  APPLICATION_TYPE
# 0      T3             27037
# 1      T4              1542
# 2      T6              1216
# 3      T5              1173
# 4     T19              1065
# 5      T8               737
# 6      T7               725
# 7     T10               528
# 8      T9               156
# 9     T13                66
# 10    T12                27
# 11  other                27

# %%
data_df['CLASSIFICATION'].value_counts(sort=True).reset_index()
# Out:
#     index  CLASSIFICATION
# 0   C1000           17326
# 1   C2000            6074
# 2   C1200            4837
# 3   C3000            1918
# 4   C2100            1883
# ..    ...             ...
# 66  C4500               1
# 67  C2570               1
# 68  C1820               1
# 69  C2500               1
# 70  C1732               1
#
# [71 rows x 2 columns]

# %%
#Similarly
other_clas = data_df['CLASSIFICATION'].value_counts().loc[lambda x: x<800]
classifications_to_replace = other_clas.index.tolist()
# Replace in dataframe
for clas in classifications_to_replace:
    data_df['CLASSIFICATION'] = data_df['CLASSIFICATION'].replace(clas,"Combined_class")
# Check to make sure binning was successful
data_df['CLASSIFICATION'].value_counts(sort=True).reset_index()
# Out:
#             index  CLASSIFICATION
# 0           C1000           17326
# 1           C2000            6074
# 2           C1200            4837
# 3  Combined_class            2261
# 4           C3000            1918
# 5           C2100            1883

# %%
data_df
# Out:
#              EIN                                               NAME  \
# 0       10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1       10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2       10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3       10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4       10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# ...          ...                                                ...
# 34294  996009318              THE LIONS CLUB OF HONOLULU KAMEHAMEHA
# 34295  996010315           INTERNATIONAL ASSOCIATION OF LIONS CLUBS
# 34296  996012607                                PTA HAWAII CONGRESS
# 34297  996015768  AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LO...
# 34298  996086871                           WATERHOUSE CHARITABLE TR
#
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS  INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1         0.0                      N      5000
# 1      Co-operative       1         1.0                      N    108590
# 2       Association       1         0.0                      N      5000
# 3             Trust       1     10000.0                      N      6692
# 4             Trust       1    100000.0                      N    142590
# ...             ...     ...         ...                    ...       ...
# 34294   Association       1         0.0                      N      5000
# 34295   Association       1         0.0                      N      5000
# 34296   Association       1         0.0                      N      5000
# 34297   Association       1         0.0                      N      5000
# 34298  Co-operative       1   1000000.0                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 12 columns]

# %%
data_df.isnull().sum()
# Out:
# EIN                       0
# NAME                      0
# APPLICATION_TYPE          0
# AFFILIATION               0
# CLASSIFICATION            0
# USE_CASE                  0
# ORGANIZATION              0
# STATUS                    0
# INCOME_AMT                0
# SPECIAL_CONSIDERATIONS    0
# ASK_AMT                   0
# IS_SUCCESSFUL             0
# dtype: int64

# %%
# Drop irrelevant columns
data_dropped = data_df.drop(['EIN', 'NAME'], axis=1)
data_dropped.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS  INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1         0.0                      N     5000
# 1  Co-operative       1         1.0                      N   108590
# 2   Association       1         0.0                      N     5000
# 3         Trust       1     10000.0                      N     6692
# 4         Trust       1    100000.0                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# drop target labels
final_df = data_dropped.drop('IS_SUCCESSFUL', axis=1)
final_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS  INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT
# 0       Association       1         0.0                      N      5000
# 1      Co-operative       1         1.0                      N    108590
# 2       Association       1         0.0                      N      5000
# 3             Trust       1     10000.0                      N      6692
# 4             Trust       1    100000.0                      N    142590
# ...             ...     ...         ...                    ...       ...
# 34294   Association       1         0.0                      N      5000
# 34295   Association       1         0.0                      N      5000
# 34296   Association       1         0.0                      N      5000
# 34297   Association       1         0.0                      N      5000
# 34298  Co-operative       1   1000000.0                      N  36500179
#
# [34299 rows x 9 columns]

# %%
X_data = pd.get_dummies((final_df), drop_first=True)
X_data
# Out:
#        STATUS  INCOME_AMT   ASK_AMT  APPLICATION_TYPE_T12  \
# 0           1         0.0      5000                     0
# 1           1         1.0    108590                     0
# 2           1         0.0      5000                     0
# 3           1     10000.0      6692                     0
# 4           1    100000.0    142590                     0
# ...       ...         ...       ...                   ...
# 34294       1         0.0      5000                     0
# 34295       1         0.0      5000                     0
# 34296       1         0.0      5000                     0
# 34297       1         0.0      5000                     0
# 34298       1   1000000.0  36500179                     0
#
#        APPLICATION_TYPE_T13  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         0                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        CLASSIFICATION_C3000  CLASSIFICATION_Combined_class  \
# 0                         0                              0
# 1                         0                              0
# 2                         1                              0
# 3                         0                              0
# 4                         0                              0
# ...                     ...                            ...
# 34294                     0                              0
# 34295                     1                              0
# 34296                     0                              0
# 34297                     1                              0
# 34298                     0                              0
#
#        USE_CASE_Heathcare  USE_CASE_Other  USE_CASE_Preservation  \
# 0                       0               0                      0
# 1                       0               0                      1
# 2                       0               0                      0
# 3                       0               0                      1
# 4                       1               0                      0
# ...                   ...             ...                    ...
# 34294                   0               0                      0
# 34295                   0               0                      0
# 34296                   0               0                      1
# 34297                   0               0                      0
# 34298                   0               0                      1
#
#        USE_CASE_ProductDev  ORGANIZATION_Co-operative  \
# 0                        1                          0
# 1                        0                          1
# 2                        1                          0
# 3                        0                          0
# 4                        0                          0
# ...                    ...                        ...
# 34294                    1                          0
# 34295                    1                          0
# 34296                    0                          0
# 34297                    1                          0
# 34298                    0                          1
#
#        ORGANIZATION_Corporation  ORGANIZATION_Trust  SPECIAL_CONSIDERATIONS_Y
# 0                             0                   0                         0
# 1                             0                   0                         0
# 2                             0                   0                         0
# 3                             0                   1                         0
# 4                             0                   1                         0
# ...                         ...                 ...                       ...
# 34294                         0                   0                         0
# 34295                         0                   0                         0
# 34296                         0                   0                         0
# 34297                         0                   0                         0
# 34298                         0                   0                         0
#
# [34299 rows x 32 columns]

# %%
X_data.shape
# Out:
# (34299, 32)

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
# assign labels denoted by y to our train and test data sets
y_label = LabelEncoder().fit_transform(data_df["IS_SUCCESSFUL"])
y_label.shape
# Out:
# (34299,)

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
import keras_tuner as kt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-89-76404554384d> in <module>
#       5 from sklearn.preprocessing import StandardScaler
#       6
# ----> 7 import tensorflow as tf
#       8 import keras_tuner as kt
#
# ModuleNotFoundError: No module named 'tensorflow'
